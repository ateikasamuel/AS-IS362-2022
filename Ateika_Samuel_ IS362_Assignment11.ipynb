# %%
# Data retrieval 
import urllib3
from urllib3 import request

# To manage json data
import json

# For pandas dataframes
import pandas as pd

reviews = "https://api.nytimes.com/svc/movies/v2/reviews/search.json?query=godfather&api-key=FrNPZ83j3dAjhXBjDzzdYa9HQrgo4XKS"
movie_reviews = pd.read_json(reviews)

movie_reviews
# Out:
#   status                                          copyright  has_more  \
# 0     OK  Copyright (c) 2022 The New York Times Company....     False
# 1     OK  Copyright (c) 2022 The New York Times Company....     False
# 2     OK  Copyright (c) 2022 The New York Times Company....     False
# 3     OK  Copyright (c) 2022 The New York Times Company....     False
# 4     OK  Copyright (c) 2022 The New York Times Company....     False
# 5     OK  Copyright (c) 2022 The New York Times Company....     False
# 6     OK  Copyright (c) 2022 The New York Times Company....     False
# 7     OK  Copyright (c) 2022 The New York Times Company....     False
# 8     OK  Copyright (c) 2022 The New York Times Company....     False
# 9     OK  Copyright (c) 2022 The New York Times Company....     False
#
#    num_results                                            results
# 0           10  {'display_title': 'The Black Godfather', 'mpaa...
# ...
